# %%
import os
import csv
import pandas as pd

us_state = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
}

emp_ids = []
emp_first_names = []
emp_last_names = []
emp_dobs = []
emp_ssns = []
emp_states = []
csvpathA = os.path.join("employee_data1.csv")
csvpathB = os.path.join("employee_data2.csv")

EmployA_df = pd.read_csv(csvpathA, encoding="utf-8")
EmployB_df = pd.read_csv(csvpathB, encoding="utf-8")

sum_df=pd.DataFrame(EmployA_df)

sum_df = EmployA_df.append(EmployB_df,ignore_index=True)

# Splitting the name into first and Last name
sum_df["FN"]= sum_df.Name.str.split(' ', expand = True)[0]
sum_df["LN"]= sum_df.Name.str.split(' ', expand = True)[1]

#Format the DOB into DD-MM-YYYY format
sum_df["DateOfBirth"]= pd.to_datetime(sum_df['DOB']).dt.strftime("%d-%m-%Y")

#lookup and replace with small state
new_sumdf= sum_df.replace({"State": us_state})

#print(new_sumdf)
# Masking the social Security number
 
for index,row in new_sumdf.iterrows():  
   split_ssn = list(row["SSN"])
   #print("SSN",row["SSN"],"Split SSN", split_ssn)
   split_ssn[0:3] = ("*", "*", "*")
   split_ssn[4:6] = ("*", "*")
   joined_ssn = "".join(split_ssn)
   new_sumdf.set_value(index,"NEWSSN", joined_ssn)

print(new_sumdf)




# Then store it into a list
#emp_ssns = emp_ssns + [joined_ssn]
# Out:
#       Emp ID                Name         DOB          SSN State         FN  \
# 0        214       Sarah Simpson   12/4/1985  282-01-8166    FL      Sarah
# 1         15       Samantha Lara    9/8/1993  848-80-7526    CO   Samantha
# 2        411       Stacy Charles  12/20/1957  658-75-8526    PA      Stacy
# 3        166        Michelle Roy   7/29/1978  794-25-3944    MI   Michelle
# 4         39       Joseph Rogers   3/28/1985  525-40-3515    MN     Joseph
# 5        423         Erica Hines  10/13/1975  034-90-6153    NY      Erica
# 6        192           Zoe Patel  12/20/1967  037-50-0817    WI        Zoe
# 7        162      Matthew Harvey   1/20/1990  244-53-0346    TN    Matthew
# 8        131         Shawn Davis   7/21/1961  309-08-1581    WV      Shawn
# 9         20       April Baldwin    8/7/1961  068-61-2014    MO      April
# 10       246     Vincent Daniels    1/6/1972  319-38-2754    MT    Vincent
# 11       525          Ann Fields   8/22/1960  752-98-7911    IA        Ann
# 12       392     Jeffrey Pearson    5/5/1979  171-82-2578    IL    Jeffrey
# 13       474     Heather Johnson   9/23/1989  724-30-0904    GA    Heather
# 14       478    Melissa Fletcher   3/14/1979  899-91-6881    RI    Melissa
# 15       101    Kimberly Alvarez    9/4/1984  138-08-8680    LA   Kimberly
# 16        52      Monica Jimenez    4/8/1988  835-26-1668    ND     Monica
# 17       182      Steven Johnson   5/28/1962  026-20-7070    NE     Steven
# 18       637          Sarah Wood   6/15/1972  235-96-6715    FL      Sarah
# 19       510      Jesus Petersen   3/28/1958  133-75-0770    OK      Jesus
# 20       122      Rhonda Rosales   4/10/1963  498-27-0286    AL     Rhonda
# 21       294   Nicole Richardson    9/9/1981  369-83-5228    LA     Nicole
